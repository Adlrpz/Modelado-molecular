# %%
import numpy as np
import matplotlib.pyplot as plt

# Cargar datos
phi_data = np.loadtxt("phi-ser-4.dat", usecols=[1])
psi_data = np.loadtxt("psi-ser-4.dat", usecols=[1])

# Crear un eje de tiempo basado en el número de datos
time_steps = np.arange(len(phi_data))

# Gráfica de evolución de φ
plt.figure(figsize=(8, 5))
plt.plot(time_steps, phi_data, marker="o", linestyle="-", markersize=2, label="Ángulo φ")
plt.xlabel("Paso de tiempo")
plt.ylabel("Ángulo φ (grados)")
plt.title("Evolución del ángulo φ de SER-4")
plt.grid()
plt.legend()
plt.savefig("phi_evolucionSER400.png", dpi=300)  # Guardar figura
plt.show()

# Gráfica de evolución de ψ
plt.figure(figsize=(8, 5))
plt.plot(time_steps, psi_data, marker="o", linestyle="-", markersize=2, label="Ángulo ψ", color="red")
plt.xlabel("Paso de tiempo (fs)")
plt.ylabel("Ángulo ψ (grados)")
plt.title("Evolución del ángulo ψ de SER-4")
plt.grid()
plt.legend()
plt.savefig("psi_evolucionSER400.png", dpi=300)
plt.show()

# Mapa de Ramachandran (φ vs ψ)
plt.figure(figsize=(7, 7))
plt.scatter(phi_data, psi_data, c="blue", alpha=0.5, s=5)  # Scatter plot
plt.xlabel("Ángulo φ (grados)")
plt.ylabel("Ángulo ψ (grados)")
plt.title("Mapa de Ramachandran de SER")
plt.xlim(-90, -10)
plt.ylim(165, 125)
plt.grid()
plt.savefig("ramachandranSER400.png", dpi=300)
plt.show()
